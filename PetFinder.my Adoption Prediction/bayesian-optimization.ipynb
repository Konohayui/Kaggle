# %%
import pandas as pd, numpy as np, scipy as sp, random as rn
import seaborn as sns, matplotlib.pyplot as plt
import json, os, gc, time, re, cv2, glob
from math import sqrt

from joblib import Parallel, delayed

from functools import partial
from math import sqrt
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold, GroupKFold
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD, NMF, LatentDirichletAllocation

from keras.applications.densenet import preprocess_input, DenseNet121
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Input, Lambda
from keras.layers import Lambda, Concatenate, AveragePooling1D, MaxPooling1D
from keras.models import Model
import keras.backend as K

from bayes_opt import BayesianOptimization

from collections import Counter, defaultdict
import lightgbm as lgbm

seed = 32
np.random.seed(seed)
rn.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

train = pd.read_csv("../input/petfinder-adoption-prediction/train/train.csv")
test = pd.read_csv("../input/petfinder-adoption-prediction/test/test.csv")
# Out:
# Using TensorFlow backend.

# %%
target = train["AdoptionSpeed"]
rescuerID = train["RescuerID"]
train.drop(["AdoptionSpeed"], axis = 1, inplace = True)

# %%
breeds = pd.read_csv("../input//petfinder-adoption-prediction/breed_labels.csv")
breeds_dict = {k:v for k, v in zip(breeds["BreedID"], breeds["BreedName"])}

train["Breed1Name"] = train["Breed1"].apply(lambda x: breeds_dict[x] if x in breeds_dict else "Unknown")
test["Breed1Name"] = test["Breed1"].apply(lambda x: breeds_dict[x] if x in breeds_dict else "Unknown")

train["Breed2Name"] = train["Breed2"].apply(lambda x: breeds_dict[x] if x in breeds_dict else "Unknown")
test["Breed2Name"] = test["Breed2"].apply(lambda x: breeds_dict[x] if x in breeds_dict else "Unknown")

# %%
for cat in ["Vaccinated", "Dewormed", "Sterilized", "Health"]:
    train[cat] = train[cat].apply(lambda x: 1 if x == 1 else 0)
    test[cat] = test[cat].apply(lambda x: 1 if x == 1 else 0)

# %%
# train["Fee"] = np.log(train["Fee"] + 1)
# test["Fee"] = np.log(test["Fee"] + 1)

# %%
def add_count_feat(data, cols):
    feat_name = "_".join(cols) + "_count"
    arr_slice = data[cols].values
    unq, unqtags, counts = np.unique(np.ravel_multi_index(arr_slice.T, arr_slice.max(0) + 1),
                                     return_inverse = True, return_counts = True)
    data[feat_name] = counts[unqtags]
    del arr_slice, unq, unqtags, counts; gc.collect()
    
    return data

train = add_count_feat(train, ["Breed1", "State"])
train = add_count_feat(train, ["Breed1", "Age"])
train = add_count_feat(train, ["Type", "State"])
train["RescuerID_count"] = train["RescuerID"].map(train["RescuerID"].value_counts())
train["RescuerID_Breed1_count"] = train["RescuerID"].map(train[["RescuerID", "Breed1"]].groupby("RescuerID")["Breed1"].count())
train["State_rescuer_count"] = train["State"].map(train[["State", "RescuerID"]].groupby("State")["RescuerID"].count())

test = add_count_feat(test, ["Breed1", "State"])
test = add_count_feat(test, ["Breed1", "Age"])
test = add_count_feat(test, ["Type", "State"])
test["RescuerID_count"] = test["RescuerID"].map(test["RescuerID"].value_counts())
test["RescuerID_Breed1_count"] = test["RescuerID"].map(train[["RescuerID", "Breed1"]].groupby("RescuerID")["Breed1"].count())
test["State_rescuer_count"] = test["State"].map(test[["State", "RescuerID"]].groupby("State")["RescuerID"].count())

count_feats = ["Breed1_State_count", "Breed1_Age_count", "Type_State_count", 
               "RescuerID_Breed1_count", "RescuerID_count", "State_rescuer_count"]

# %%
train["DescriptionLen"] = train["Description"].fillna("No Description").apply(len)
test["DescriptionLen"] = test["Description"].fillna("No Description").apply(len)

# %%
def add_agg_feats(dataframe):
    aggs = {}
    aggs["Age"] = ["mean", "std", "median", "var"]
    aggs["Fee"] = ["mean", "std", "median", "var"]
    aggs["Quantity"] = ["mean", "std", "median", "var"]
    aggs["PhotoAmt"] = ["mean", "std", "median", "var"]
    aggs["VideoAmt"] = ["mean", "std", "var"]
    aggs["DescriptionLen"] = ["mean", "std", "median", "var"]
    aggs["Vaccinated"] = ["sum"]
    aggs["Dewormed"] = ["sum"]
    aggs["Sterilized"] = ["sum"]
    aggs["Health"] = ["sum"]
    
    for col in [["Breed1"], ["RescuerID"], ["State"], ["RescuerID", "State"], 
                 ["RescuerID", "Breed1"], ["RescuerID", "Gender"], ["Breed1", "Breed2"]]:
        agg_feat = dataframe.groupby(col).agg(aggs)
        agg_feat.columns = ["".join(col) + "_" + "_".join(c) for c in agg_feat.columns.values]
        agg_feat = agg_feat[agg_feat.columns].fillna(-1)
        agg_feat.reset_index(inplace = True)
        dataframe = pd.merge(dataframe, agg_feat, on = col, how = "left")
        
    return dataframe

num_feat = len(train.columns)
train = add_agg_feats(train)
test = add_agg_feats(test)
agg_feats = list(train.columns[num_feat:])

# %%
def get_sentiment(file_path, df):
    file_path = file_path + df["PetID"] + ".json"
    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            file = json.load(f)
        doc_sent_mag = file["documentSentiment"]["magnitude"]
        doc_sent_score = file["documentSentiment"]["score"]
        file_entities = [x["name"] for x in file["entities"]]
        entities = " ".join(file_entities)
        
        file_sentences_sentiment = [x["sentiment"] for x in file["sentences"]]
        file_sentences_sentiment = pd.DataFrame.from_dict(file_sentences_sentiment, 
                                                          orient = "columns")
        sentiment_mag_sum = file_sentences_sentiment["magnitude"].sum(axis = 0)
        sentiment_mag_mean = file_sentences_sentiment["magnitude"].mean(axis = 0)
        sentiment_mag_std = file_sentences_sentiment["magnitude"].std(axis = 0)
        
        sentiment_score_sum = file_sentences_sentiment["score"].sum(axis = 0)
        sentiment_score_mean = file_sentences_sentiment["score"].mean(axis = 0)
        sentiment_score_std = file_sentences_sentiment["score"].std(axis = 0)
        return pd.Series([doc_sent_mag, doc_sent_score, entities, 
                          sentiment_mag_sum, sentiment_mag_mean,
                          sentiment_score_sum, sentiment_score_mean,
                          sentiment_mag_std, sentiment_score_std], 
                         index = ["doc_sent_mag", "doc_sent_score", "entities", 
                                  "sentiment_mag_sum", "sentiment_mag_mean",
                                  "sentiment_score_sum", "sentiment_score_mean",
                                  "sentiment_mag_std", "sentiment_score_std"])
    else:
        return pd.Series([-1, -1, "No Entities", -1, -1, -1, -1, -1, -1], 
                         index = ["doc_sent_mag", "doc_sent_score", "entities", 
                                  "sentiment_mag_sum", "sentiment_mag_mean",
                                  "sentiment_score_sum", "sentiment_score_mean",
                                  "sentiment_mag_std", "sentiment_score_std"])

train_path = "../input/petfinder-adoption-prediction/train_sentiment/"
test_path = "../input/petfinder-adoption-prediction/test_sentiment/"

train[["doc_sent_mag", "doc_sent_score", "entities", 
       "sentiment_mag_sum", "sentiment_mag_mean",
       "sentiment_score_sum", "sentiment_score_mean",
       "sentiment_mag_std", "sentiment_score_std"]] = train[["PetID"]].apply(lambda pet_id: get_sentiment(train_path, pet_id), axis = 1)
test[["doc_sent_mag", "doc_sent_score", "entities", 
      "sentiment_mag_sum", "sentiment_mag_mean",
      "sentiment_score_sum", "sentiment_score_mean",
      "sentiment_mag_std", "sentiment_score_std"]] = test[["PetID"]].apply(lambda pet_id: get_sentiment(test_path, pet_id), axis = 1)

# %%
class PetFinderParser(object):
    def __init__(self):
        None
        
    def open_json_file(self, file_path):
        with open(file_path, "r", encoding = "utf-8") as f:
            file_data = json.load(f)
        return file_data
    
    def get_metadata(self, file_data):
    
        file_keys = list(file_data.keys())
    
        if "labelAnnotations" in file_keys:
            file_annots = file_data["labelAnnotations"][:int(len(file_data["labelAnnotations"])*0.3)]
            file_top_score = np.asarray([x["score"] for x in file_annots]).mean()
            file_top_topicality = np.asarray([x["topicality"] for x in file_annots]).mean()
            file_top_desc = [x["description"] for x in file_annots]
        else:
            file_top_score = 0
            file_top_topicality = 0
            file_top_desc = [""]
        
        file_colors = file_data["imagePropertiesAnnotation"]["dominantColors"]["colors"]
        file_crops = file_data["cropHintsAnnotation"]["cropHints"]
        file_color_score = np.asarray([x["score"] for x in file_colors]).mean()
        file_color_pixelfrac = np.asarray([x["pixelFraction"] for x in file_colors]).mean()
        file_crop_conf = np.asarray([x["confidence"] for x in file_crops]).mean()
        
        try:
            file_color_red = np.asarray([x["color"]["red"] for x in file_colors]).mean()
            file_color_green = np.asarray([x["color"]["green"] for x in file_colors]).mean()
            file_color_blue = np.asarray([x["color"]["blue"] for x in file_colors]).mean()
        except:
            file_color_red = 0
            file_color_green = 0
            file_color_blue = 0
            
        if "boundingPoly" in file_crops[0].keys():
            verterx_x = np.array([x["boundingPoly"]["vertices"][2]["x"] for x in file_crops]).mean()
            verterx_y = np.array([x["boundingPoly"]["vertices"][2]["y"] for x in file_crops]).mean()
        else:
            verterx_x = 0
            verterx_y = 0
            
        if "importanceFraction" in file_crops[0].keys():
            file_crop_importance = np.asarray([x["importanceFraction"] for x in file_crops]).mean()
        else:
            file_crop_importance = 0
        
        metadata = {"annot_score": file_top_score,
                    "annot_topicality": file_top_topicality,
                    "red": file_color_red,
                    "green": file_color_green,
                    "blue": file_color_blue,
                    "verterx_x": verterx_x,
                    "verterx_y": verterx_y,
                    "annot_desc": " ".join(file_top_desc),
                    "color_score": file_color_score,
                    "color_pixelfrac": file_color_pixelfrac,
                    "crop_confidence": file_crop_conf,
                    "crop_importance": file_crop_importance}
    
        metadata_df = pd.DataFrame.from_dict(metadata, orient = "index").T
        metadata_df = metadata_df.add_prefix("metadata_")
    
        return metadata_df

def extract_metadata(mode = "", pet_id = ""):
    metadata_dfs = []
    file_name = "../input/petfinder-adoption-prediction/{}_metadata/{}*.json".format(mode, pet_id)
    metadata_file_names = sorted(glob.glob(file_name))
    
    if len(metadata_file_names) > 0:
        for file in metadata_file_names:
            file_data = pet_parser.open_json_file(file)
            partial_metadata = pet_parser.get_metadata(file_data)
            partial_metadata["PetID"] = pet_id
            metadata_dfs.append(partial_metadata)
        metadata_dfs = pd.concat(metadata_dfs, ignore_index = True, sort = False)
        
    return metadata_dfs

pet_parser = PetFinderParser()

# %%
train_metadata = Parallel(n_jobs = 6, 
                          verbose = 1)(delayed(extract_metadata)(mode = "train", pet_id = pet_id) 
                                       for pet_id in train["PetID"].values)
train_metadata = [pd.DataFrame(metadata) for metadata in train_metadata]
train_metadata = pd.concat(train_metadata, ignore_index = True, sort = False)

test_metadata = Parallel(n_jobs = 6, 
                         verbose = 1)(delayed(extract_metadata)(mode = "test", pet_id = pet_id)
                                       for pet_id in test["PetID"].values)
test_metadata = [pd.DataFrame(metadata) for metadata in test_metadata]
test_metadata = pd.concat(test_metadata, ignore_index = True, sort = False)
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=6)]: Done 4038 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=6)]: Done 4988 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done 6038 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=6)]: Done 7188 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 8438 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=6)]: Done 9788 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=6)]: Done 11238 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=6)]: Done 12788 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=6)]: Done 14438 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=6)]: Done 14993 out of 14993 | elapsed: 19.2min finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done 3948 out of 3948 | elapsed:  1.9min finished

# %%
def agg_metadata(metadata):
    aggre = ["mean", "sum", "median", "std"]
    metadata_desc = metadata.groupby(["PetID"])["metadata_annot_desc"].unique()
    metadata_desc = metadata_desc.reset_index()
    metadata_desc["metadata_annot_desc"] = metadata_desc["metadata_annot_desc"].apply(lambda x: " ".join(x))
    
    metadata = metadata.drop(["metadata_annot_desc"], axis = 1)
    for col in metadata.columns:
        if "PetID" not in col:
            metadata[col] = metadata[col].astype(float)
    metadata_agg = metadata.groupby(["PetID"]).agg(aggre)
    metadata_agg.columns = pd.Index(["{}_{}_{}".format("metadata", c[0], c[1].upper()) for c in metadata_agg.columns.tolist()])
    metadata_agg = metadata_agg.reset_index()
    
    return metadata_desc, metadata_agg

train_meta_desc, train_meta_agg = agg_metadata(train_metadata)
test_meta_desc, test_meta_agg = agg_metadata(test_metadata)

meta_agg_feats = list(train_meta_agg.columns)

# %%
train = train.merge(train_meta_desc, how = "left", on = "PetID")
train = train.merge(train_meta_agg, how = "left", on = "PetID")

test = test.merge(test_meta_desc, how = "left", on = "PetID")
test = test.merge(test_meta_agg, how = "left", on = "PetID")

train[train_meta_agg.columns] = train[train_meta_agg.columns].fillna(-1)
test[train_meta_agg.columns] = test[train_meta_agg.columns].fillna(-1)

del train_meta_desc, train_meta_agg, test_meta_desc, test_meta_agg; gc.collect()
# Out:
# 112

# %%
train_desc = train["entities"].fillna("no entity")
tfidf_vec = TfidfVectorizer()
tfidf_vec.fit(train_desc)
train_tfidf = tfidf_vec.transform(train_desc)
print(train_tfidf.shape)

svd_components = 10
svd = TruncatedSVD(n_components = svd_components, random_state = seed)
svd.fit(train_tfidf)
train_tfidf_svd = svd.transform(train_tfidf)

test_desc = test["entities"].fillna("no entity")
test_tfidf = tfidf_vec.transform(test_desc)
test_tfidf_svd = svd.transform(test_tfidf)

train_tfidf_svd = pd.DataFrame(train_tfidf_svd, columns = ["enti_tfitf_svd_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_svd], axis = 1)
test_tfidf_svd = pd.DataFrame(test_tfidf_svd, columns = ["enti_tfitf_svd_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_svd], axis = 1)

enti_tfidf_svd_feats = list(train_tfidf_svd.columns)

nmf = NMF(n_components = svd_components, random_state = seed)
nmf.fit(train_tfidf)
train_tfidf_nmf = nmf.transform(train_tfidf)
test_tfidf_nmf = nmf.transform(test_tfidf)

train_tfidf_nmf = pd.DataFrame(train_tfidf_nmf, columns = ["enti_tfitf_nmf_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_nmf], axis = 1)
test_tfidf_nmf = pd.DataFrame(test_tfidf_nmf, columns = ["enti_tfitf_nmf_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_nmf], axis = 1)

enti_tfidf_nmf_feats = list(train_tfidf_nmf.columns)

train.drop(["entities"], axis = 1, inplace = True); gc.collect()
test.drop(["entities"], axis = 1, inplace = True); gc.collect()
del train_tfidf, test_tfidf, train_tfidf_svd, test_tfidf_svd; gc.collect()
del train_tfidf_nmf, test_tfidf_nmf; gc.collect()
# Out:
# (14993, 12306)
# 0

# %%
train_desc = train["metadata_annot_desc"].fillna("no description").values
tfidf_vec = TfidfVectorizer()
tfidf_vec.fit(train_desc)
train_tfidf = tfidf_vec.transform(train_desc)
print(train_tfidf.shape)

svd_components = 10
svd = TruncatedSVD(n_components = svd_components, random_state = seed)
svd.fit(train_tfidf)
train_tfidf_svd = svd.transform(train_tfidf)

test_desc = test["metadata_annot_desc"].fillna("no description").values
test_tfidf = tfidf_vec.transform(test_desc)
test_tfidf_svd = svd.transform(test_tfidf)

train_tfidf_svd = pd.DataFrame(train_tfidf_svd, columns = ["meta_tfitf_svd_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_svd], axis = 1)
test_tfidf_svd = pd.DataFrame(test_tfidf_svd, columns = ["meta_tfitf_svd_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_svd], axis = 1)

meta_tfidf_svd_feats = list(train_tfidf_svd.columns)

nmf = NMF(n_components = svd_components, random_state = seed)
nmf.fit(train_tfidf)
train_tfidf_nmf = nmf.transform(train_tfidf)
test_tfidf_nmf = nmf.transform(test_tfidf)

train_tfidf_nmf = pd.DataFrame(train_tfidf_nmf, columns = ["meta_tfitf_nmf_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_nmf], axis = 1)
test_tfidf_nmf = pd.DataFrame(test_tfidf_nmf, columns = ["meta_tfitf_nmf_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_nmf], axis = 1)

meta_tfidf_nmf_feats = list(train_tfidf_nmf.columns)

train.drop(["metadata_annot_desc"], axis = 1, inplace = True); gc.collect()
test.drop(["metadata_annot_desc"], axis = 1, inplace = True); gc.collect()
del train_tfidf, test_tfidf, train_tfidf_svd, test_tfidf_svd; gc.collect()
del train_tfidf_nmf, test_tfidf_nmf; gc.collect()
# Out:
# (14993, 429)
# 0

# %%
train_desc = train["Description"].fillna("no description").values
tfidf_vec = TfidfVectorizer()
tfidf_vec.fit(train_desc)
train_tfidf = tfidf_vec.transform(train_desc)

svd_components = 30
svd = TruncatedSVD(n_components = svd_components, random_state = seed)
svd.fit(train_tfidf)
train_tfidf_svd = svd.transform(train_tfidf)
print(train_tfidf.shape)

test_desc = test["Description"].fillna("no description").values
test_tfidf = tfidf_vec.transform(test_desc)
test_tfidf_svd = svd.transform(test_tfidf)

train_tfidf_svd = pd.DataFrame(train_tfidf_svd, columns = ["tfitf_svd_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_svd], axis = 1)
test_tfidf_svd = pd.DataFrame(test_tfidf_svd, columns = ["tfitf_svd_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_svd], axis = 1)

tfidf_svd_feats = list(train_tfidf_svd.columns)

nmf = NMF(n_components = svd_components, random_state = seed)
nmf.fit(train_tfidf)
train_tfidf_nmf = nmf.transform(train_tfidf)
test_tfidf_nmf = nmf.transform(test_tfidf)

train_tfidf_nmf = pd.DataFrame(train_tfidf_nmf, columns = ["tfitf_nmf_{}".format(i) for i in range(svd_components)])
train = pd.concat([train, train_tfidf_nmf], axis = 1)
test_tfidf_nmf = pd.DataFrame(test_tfidf_nmf, columns = ["tfitf_nmf_{}".format(i) for i in range(svd_components)])
test = pd.concat([test, test_tfidf_nmf], axis = 1)

tfidf_nmf_feats = list(train_tfidf_nmf.columns)

train.drop(["Description"], axis = 1, inplace = True); gc.collect()
test.drop(["Description"], axis = 1, inplace = True); gc.collect()
del train_tfidf, test_tfidf, train_tfidf_svd, test_tfidf_svd; gc.collect()
del train_tfidf_nmf, test_tfidf_nmf; gc.collect()
# Out:
# (14993, 21209)
# 0

# %%
train["Name"] = train["Name"].replace(["", "No Name", "No Name Yet"], "No Name")
test["Name"] = test["Name"].replace(["", "No Name", "No Name Yet"], "No Name")

# %%
train_comb = train[["Name", "Breed1Name", "Breed2Name", "RescuerID"]].astype(str).apply(lambda x: " ".join(x), axis = 1)
test_comb = test[["Name", "Breed1Name", "Breed2Name", "RescuerID"]].astype(str).apply(lambda x: " ".join(x), axis = 1)

tfidf_vec = TfidfVectorizer(min_df = 2, ngram_range = (1, 3))
tfidf_vec.fit(train_comb)
train_comb_vec = tfidf_vec.transform(train_comb)
test_comb_vec = tfidf_vec.transform(test_comb)
print(train_comb_vec.shape)

lad_components = 10
lda = LatentDirichletAllocation(n_components = lad_components, random_state = seed)
lda.fit(train_comb_vec)
train_comb_lda = lda.transform(train_comb_vec)
test_comb_lda = lda.transform(test_comb_vec)

train_comb_lda = pd.DataFrame(train_comb_lda, columns = ["lda_{}".format(i) for i in range(lad_components)])
train = pd.concat([train, train_comb_lda], axis = 1)
test_comb_lda = pd.DataFrame(test_comb_lda, columns = ["lda_{}".format(i) for i in range(lad_components)])
test = pd.concat([test, test_comb_lda], axis = 1)

lda_feats = list(train_comb_lda.columns)
del train_comb_vec, test_comb_vec, train_comb_lda, test_comb_lda; gc.collect()
# Out:
# (14993, 12941)
# 32

# %%
import tensorflow as tf
session_conf = tf.ConfigProto(intra_op_parallelism_threads = 1,
                              inter_op_parallelism_threads = 1)
tf.set_random_seed(seed)
sess = tf.Session(graph = tf.get_default_graph(), config = session_conf)
from keras import backend as K
K.set_session(sess)

image_size = 256
batch_size = 128

def resize_to_square(image, image_size = image_size):
    old_size = image.shape[:2]
    ratio = float(image_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    image = cv2.resize(image, (new_size[1], new_size[0]))
    delta_w = image_size - new_size[1]
    delta_h = image_size - new_size[0]
    top, bottom = delta_h//2, delta_h - (delta_h//2)
    left, right = delta_w//2, delta_w - (delta_w//2)
    color = [0, 0, 0]
    new_image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value = color)
    return new_image

def load_image(path, pet_id):
    image = cv2.imread(f'{path}{pet_id}-1.jpg')
    new_image = resize_to_square(image)
    new_image = preprocess_input(new_image)
    return new_image

inp = Input((image_size, image_size, 3))
backbone = DenseNet121(input_tensor = inp, 
                       weights = "../input/densenet-keras/DenseNet-BC-121-32-no-top.h5",
                       include_top = False)
x = backbone.output
x = GlobalAveragePooling2D()(x)
x = Lambda(lambda x: K.expand_dims(x, axis = -1))(x)
x = AveragePooling1D(4)(x)
out = Lambda(lambda x: x[:, :, 0])(x)
image_model = Model(inp, out)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def get_image_features(file_path, pet_ids, image_model = image_model, batch_size = batch_size):
    image_features = {}
    n_batches = len(pet_ids)//batch_size + 1
    for b in range(n_batches):
        start = b*batch_size
        end = (b+1)*batch_size
        batch_pets = pet_ids[start:end]
        batch_images = np.zeros((len(batch_pets),image_size, image_size, 3))
        for i, pet_id in enumerate(batch_pets):
            try:
                batch_images[i] = load_image(file_path, pet_id)
            except:
                pass
            
        batch_preds = image_model.predict(batch_images)
        for i, pet_id in enumerate(batch_pets):
            image_features[pet_id] = batch_preds[i]
            
    return image_features

train_image_path = "../input/petfinder-adoption-prediction/train_images/"
test_image_path = "../input/petfinder-adoption-prediction/test_images/"

train_image_features = get_image_features(train_image_path, train["PetID"].values)
test_image_features = get_image_features(test_image_path, test["PetID"].values)

# %%
train_image_feat = pd.DataFrame.from_dict(train_image_features, orient = "index")
train_image_feat.columns = ["pic_{}".format(i) for i in range(train_image_feat.shape[1])]
pic_features = train_image_feat.columns

train_image_feat = train_image_feat.reset_index()
train_image_feat.rename({"index": "PetID"}, axis = "columns", inplace = True)

test_image_feat = pd.DataFrame.from_dict(test_image_features, orient = "index")
test_image_feat.columns = ["pic_{}".format(i) for i in range(test_image_feat.shape[1])]
test_image_feat = test_image_feat.reset_index()
test_image_feat.rename({"index": "PetID"}, axis = "columns", inplace = True)

# %%
pic_features = ["pic_{}".format(i) for i in range(256)]
svd = TruncatedSVD(n_components = 32, random_state = seed)
svd.fit(train_image_feat[pic_features])

train_image_feat_svd = svd.transform(train_image_feat[pic_features])
test_image_feat_svd = svd.transform(test_image_feat[pic_features])

# %%
train_image_feat_svd = pd.DataFrame(train_image_feat_svd, columns = ["pic_svd_{}".format(i) for i in range(32)])
train = pd.concat([train, train_image_feat_svd], axis = 1)
test_image_feat_svd = pd.DataFrame(test_image_feat_svd, columns = ["pic_svd_{}".format(i) for i in range(32)])
test = pd.concat([test, test_image_feat_svd], axis = 1)

image_svd_feat = list(train_image_feat_svd.columns)

# %%
# The following 3 functions have been taken from Ben Hamner's github repository
# https://github.com/benhamner/Metrics
def confusion_matrix(rater_a, rater_b, min_rating=None, max_rating=None):
    """
    Returns the confusion matrix between rater's ratings
    """
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(rater_a + rater_b)
    if max_rating is None:
        max_rating = max(rater_a + rater_b)
    num_ratings = int(max_rating - min_rating + 1)
    conf_mat = [[0 for i in range(num_ratings)]
                for j in range(num_ratings)]
    for a, b in zip(rater_a, rater_b):
        conf_mat[a - min_rating][b - min_rating] += 1
    return conf_mat


def histogram(ratings, min_rating=None, max_rating=None):
    """
    Returns the counts of each type of rating that a rater made
    """
    if min_rating is None:
        min_rating = min(ratings)
    if max_rating is None:
        max_rating = max(ratings)
    num_ratings = int(max_rating - min_rating + 1)
    hist_ratings = [0 for x in range(num_ratings)]
    for r in ratings:
        hist_ratings[r - min_rating] += 1
    return hist_ratings


def quadratic_weighted_kappa(y, y_pred):
    """
    Calculates the quadratic weighted kappa
    axquadratic_weighted_kappa calculates the quadratic weighted kappa
    value, which is a measure of inter-rater agreement between two raters
    that provide discrete numeric ratings.  Potential values range from -1
    (representing complete disagreement) to 1 (representing complete
    agreement).  A kappa value of 0 is expected if all agreement is due to
    chance.
    quadratic_weighted_kappa(rater_a, rater_b), where rater_a and rater_b
    each correspond to a list of integer ratings.  These lists must have the
    same length.
    The ratings should be integers, and it is assumed that they contain
    the complete range of possible ratings.
    quadratic_weighted_kappa(X, min_rating, max_rating), where min_rating
    is the minimum possible rating, and max_rating is the maximum possible
    rating
    """
    rater_a = y
    rater_b = y_pred
    min_rating=None
    max_rating=None
    rater_a = np.array(rater_a, dtype=int)
    rater_b = np.array(rater_b, dtype=int)
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
    conf_mat = confusion_matrix(rater_a, rater_b,
                                min_rating, max_rating)
    num_ratings = len(conf_mat)
    num_scored_items = float(len(rater_a))

    hist_rater_a = histogram(rater_a, min_rating, max_rating)
    hist_rater_b = histogram(rater_b, min_rating, max_rating)

    numerator = 0.0
    denominator = 0.0

    for i in range(num_ratings):
        for j in range(num_ratings):
            expected_count = (hist_rater_a[i] * hist_rater_b[j]
                              / num_scored_items)
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0)
            numerator += d * conf_mat[i][j] / num_scored_items
            denominator += d * expected_count / num_scored_items

    return (1.0 - numerator / denominator)

# %%
class OptimizedRounder(object):
    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4

        ll = quadratic_weighted_kappa(y, X_p)
        return -ll

    def fit(self, X, y):
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        initial_coef = [0.5, 1.5, 2.5, 3.5]
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method='nelder-mead')

    def predict(self, X, coef):
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        return X_p

    def coefficients(self):
        return self.coef_['x']
    
def rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

# %%
def stratified_group_k_fold(X, y, groups, k, seed=None):
    labels_num = np.max(y) + 1
    y_counts_per_group = defaultdict(lambda: np.zeros(labels_num))
    y_distr = Counter()
    for label, g in zip(y, groups):
        y_counts_per_group[g][label] += 1
        y_distr[label] += 1

    y_counts_per_fold = defaultdict(lambda: np.zeros(labels_num))
    groups_per_fold = defaultdict(set)

    def eval_y_counts_per_fold(y_counts, fold):
        y_counts_per_fold[fold] += y_counts
        std_per_label = []
        for label in range(labels_num):
            label_std = np.std([y_counts_per_fold[i][label] / y_distr[label] for i in range(k)])
            std_per_label.append(label_std)
        y_counts_per_fold[fold] -= y_counts
        return np.mean(std_per_label)
    
    groups_and_y_counts = list(y_counts_per_group.items())
    rn.Random(seed).shuffle(groups_and_y_counts)

    for g, y_counts in sorted(groups_and_y_counts, key=lambda x: -np.std(x[1])):
        best_fold = None
        min_eval = None
        for i in range(k):
            fold_eval = eval_y_counts_per_fold(y_counts, i)
            if min_eval is None or fold_eval < min_eval:
                min_eval = fold_eval
                best_fold = i
        y_counts_per_fold[best_fold] += y_counts
        groups_per_fold[best_fold].add(g)

    all_groups = set(groups)
    for i in range(k):
        train_groups = all_groups - groups_per_fold[i]
        test_groups = groups_per_fold[i]

        train_indices = [i for i, g in enumerate(groups) if g in train_groups]
        test_indices = [i for i, g in enumerate(groups) if g in test_groups]

        yield train_indices, test_indices

# %%
num_feat = ["Age", "VideoAmt", "PhotoAmt", "Quantity", "Fee", "doc_sent_mag", "doc_sent_score", 
            "sentiment_mag_sum", "sentiment_mag_mean", "sentiment_score_sum", 
            "sentiment_score_mean", "sentiment_mag_std", "sentiment_score_std"]
num_feat = num_feat + count_feats + meta_agg_feats + meta_tfidf_svd_feats + meta_tfidf_nmf_feats
num_feat = num_feat + enti_tfidf_svd_feats + enti_tfidf_nmf_feats + agg_feats
num_feat = num_feat + tfidf_svd_feats + image_svd_feat + lda_feats + tfidf_nmf_feats 
cat_feat = ["Type", "Breed1", "Breed2", "Gender", "Color1", "Color2", "Color3", "MaturitySize",
            "FurLength", "Vaccinated", "Dewormed", "Sterilized", "Health", "State"]
predictors = list(set(num_feat + cat_feat))
if "PetID" in predictors:
    predictors.remove("PetID")

train[cat_feat] = train[cat_feat].astype("category")
test[cat_feat] = test[cat_feat].astype("category")

train_X = train[predictors].copy()

# %%
def LGBM_bayesian(num_leaves,
                  max_depth,
                  max_bin,
                  bagging_fraction,
                  bagging_freq,
                  feature_fraction,
                  min_split_gain,
                  min_child_samples,
                  min_child_weight,
                  lambda_l2):
    
    params = {"application": "regression",
              "boosting": "gbdt",
              "metric": "rmse",
              "learning_rate": 0.005,
              "num_leaves": int(num_leaves),
              "max_depth": int(max_depth),
              "max_bin": int(max_bin),
              "bagging_fraction": bagging_fraction,
              "bagging_freq": int(bagging_freq),
              "feature_fraction": feature_fraction,
              "min_split_gain": min_split_gain,
              "lambda_l2": lambda_l2,
              "min_child_samples": int(min_child_samples),
              "min_child_weight": min_child_weight,
              "verbosity": -1,
              "num_threads": 4,
              "seed": seed}
    
    oof_pred = np.zeros((train.shape[0]))

    kfold = GroupKFold(n_splits = 5)
    kfold.get_n_splits(train_X, target, rescuerID)
    
    for i, (train_idx, val_idx) in enumerate(kfold.split(train_X, target, rescuerID)):
#     for i, (train_idx, val_idx) in enumerate(stratified_group_k_fold(train_X, target, rescuerID, 5, seed = seed)):

        evals_results = {}
        X_train, y_train = train_X.iloc[train_idx], target[train_idx]
        X_val, y_val = train_X.iloc[val_idx], target[val_idx]
    
        dtrain = lgbm.Dataset(X_train, label = y_train)
        dval = lgbm.Dataset(X_val, label = y_val)
        del X_train, y_train; gc.collect()
    
        model = lgbm.train(params, dtrain, valid_sets = [dtrain, dval], 
                           valid_names = ["train", "val"], evals_result = evals_results,
                           num_boost_round = 10000, early_stopping_rounds = 500,
                           verbose_eval = 1000)
        del dtrain, dval; gc.collect()
    
        n_estimator = model.best_iteration
        val_pred = model.predict(X_val, num_iteration = n_estimator)
        oof_pred[val_idx] = val_pred

        opt_round = OptimizedRounder()
        opt_round.fit(val_pred, y_val)
        coefficients = opt_round.coefficients()
        val_pred = opt_round.predict(val_pred, coefficients)
        qwk = quadratic_weighted_kappa(y_val, val_pred)
        print("QWK score is {}".format(qwk))
        del X_val, y_val; gc.collect()
            
    opt_round = OptimizedRounder()
    opt_round.fit(oof_pred, target)
    coeffs = opt_round.coefficients()
    oof_pred = opt_round.predict(oof_pred, coeffs).astype(int)
    qwk = quadratic_weighted_kappa(target, oof_pred)
    
    return qwk

# %%
import warnings

bounds = {"num_leaves": (70, 150),
          "max_depth": (8, 12),
          "max_bin": (30, 100),
          "bagging_fraction": (0.5, 0.9),
          "bagging_freq": (1, 50),
          "feature_fraction": (0.5, 0.9),
          "min_split_gain": (0.0, 1.0),
          "min_child_samples": (25, 150),
          "min_child_weight": (0.0, 1.0),
          "lambda_l2": (0.0, 2.0)}

lgbm_bayesopt = BayesianOptimization(LGBM_bayesian, bounds, random_state = seed)

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    lgbm_bayesopt.maximize(init_points = 5, n_iter = 50, acq = "ucb")
# Out:
# |   iter    |  target   | baggin... | baggin... | featur... | lambda_l2 |  max_bin  | max_depth | min_ch... | min_ch... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.633777	val's rmse: 1.03969
# [2000]	train's rmse: 0.470148	val's rmse: 1.0373
# [3000]	train's rmse: 0.431709	val's rmse: 1.03675
# Early stopping, best iteration is:
# [2719]	train's rmse: 0.43701	val's rmse: 1.03642
# QWK score is 0.4044774375094806
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.632543	val's rmse: 1.06449
# [2000]	train's rmse: 0.472592	val's rmse: 1.0615
# [3000]	train's rmse: 0.430993	val's rmse: 1.06181
# Early stopping, best iteration is:
# [2500]	train's rmse: 0.443499	val's rmse: 1.06138
# QWK score is 0.41924338368358893
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.635083	val's rmse: 1.04794
# Early stopping, best iteration is:
# [1178]	train's rmse: 0.596933	val's rmse: 1.04725
# QWK score is 0.41588635972066834
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.63588	val's rmse: 1.04762
# [2000]	train's rmse: 0.475508	val's rmse: 1.04397
# Early stopping, best iteration is:
# [1884]	train's rmse: 0.486062	val's rmse: 1.04375
# QWK score is 0.44632777131312706
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.628102	val's rmse: 1.06955
# [2000]	train's rmse: 0.465374	val's rmse: 1.06863
# Early stopping, best iteration is:
# [1709]	train's rmse: 0.493964	val's rmse: 1.06854
# QWK score is 0.4106060700802797
# |  1        |  0.4296   |  0.8436   |  19.26    |  0.7221   |  1.911    |  81.57    |  11.26    |  37.64    |  0.9285   |  0.6091   |  117.7    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.861916	val's rmse: 1.03889
# Early stopping, best iteration is:
# [1315]	train's rmse: 0.819784	val's rmse: 1.03736
# QWK score is 0.42154744951350254
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.856706	val's rmse: 1.06497
# [2000]	train's rmse: 0.733375	val's rmse: 1.06194
# Early stopping, best iteration is:
# [1658]	train's rmse: 0.769762	val's rmse: 1.06014
# QWK score is 0.43777638376374306
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.858214	val's rmse: 1.0462
# [2000]	train's rmse: 0.737306	val's rmse: 1.04526
# Early stopping, best iteration is:
# [1683]	train's rmse: 0.772379	val's rmse: 1.04432
# QWK score is 0.4187941867937376
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.857739	val's rmse: 1.05119
# [2000]	train's rmse: 0.737411	val's rmse: 1.04716
# Early stopping, best iteration is:
# [2205]	train's rmse: 0.717541	val's rmse: 1.04671
# QWK score is 0.44419311129092065
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.854979	val's rmse: 1.06988
# [2000]	train's rmse: 0.734657	val's rmse: 1.06858
# Early stopping, best iteration is:
# [1923]	train's rmse: 0.742323	val's rmse: 1.06812
# QWK score is 0.44774116888673243
# |  2        |  0.4319   |  0.5367   |  17.91    |  0.7651   |  0.8834   |  68.6     |  10.81    |  98.68    |  0.04993  |  0.5618   |  131.3    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.623314	val's rmse: 1.03947
# [2000]	train's rmse: 0.431861	val's rmse: 1.03624
# [3000]	train's rmse: 0.31381	val's rmse: 1.0367
# Early stopping, best iteration is:
# [2530]	train's rmse: 0.361473	val's rmse: 1.03566
# QWK score is 0.4146126253167015
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.623711	val's rmse: 1.06403
# Early stopping, best iteration is:
# [1255]	train's rmse: 0.568391	val's rmse: 1.06353
# QWK score is 0.4288783289085307
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.623851	val's rmse: 1.0469
# Early stopping, best iteration is:
# [1232]	train's rmse: 0.57541	val's rmse: 1.04655
# QWK score is 0.40117424726478
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.628434	val's rmse: 1.05058
# [2000]	train's rmse: 0.44328	val's rmse: 1.04621
# Early stopping, best iteration is:
# [2169]	train's rmse: 0.417646	val's rmse: 1.04589
# QWK score is 0.44845604939782713
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.612182	val's rmse: 1.0695
# [2000]	train's rmse: 0.421248	val's rmse: 1.06887
# Early stopping, best iteration is:
# [1677]	train's rmse: 0.473291	val's rmse: 1.06831
# QWK score is 0.4262143159336783
# |  3        |  0.4305   |  0.8644   |  5.553    |  0.861    |  0.9219   |  61.64    |  12.0     |  45.3     |  0.7094   |  0.1606   |  134.9    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.907323	val's rmse: 1.03866
# [2000]	train's rmse: 0.814724	val's rmse: 1.03522
# Early stopping, best iteration is:
# [1977]	train's rmse: 0.816633	val's rmse: 1.03495
# QWK score is 0.4067608189246905
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.905071	val's rmse: 1.06238
# Early stopping, best iteration is:
# [1109]	train's rmse: 0.892908	val's rmse: 1.06054
# QWK score is 0.4328229724872489
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.903746	val's rmse: 1.04604
# [2000]	train's rmse: 0.809022	val's rmse: 1.04146
# Early stopping, best iteration is:
# [2229]	train's rmse: 0.791216	val's rmse: 1.04084
# QWK score is 0.409284506860069
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.904611	val's rmse: 1.04742
# [2000]	train's rmse: 0.809898	val's rmse: 1.03983
# [3000]	train's rmse: 0.737447	val's rmse: 1.03897
# Early stopping, best iteration is:
# [2916]	train's rmse: 0.743284	val's rmse: 1.03853
# QWK score is 0.4587403208507329
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.901152	val's rmse: 1.06538
# [2000]	train's rmse: 0.808542	val's rmse: 1.06154
# Early stopping, best iteration is:
# [2376]	train's rmse: 0.779479	val's rmse: 1.06076
# QWK score is 0.4509665402358597
# |  4        |  0.4362   |  0.5141   |  27.21    |  0.5666   |  0.6168   |  33.15    |  8.954    |  109.4    |  0.7824   |  0.6952   |  96.32    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.791925	val's rmse: 1.03806
# [2000]	train's rmse: 0.652959	val's rmse: 1.03601
# Early stopping, best iteration is:
# [1768]	train's rmse: 0.681473	val's rmse: 1.03545
# QWK score is 0.41342505835905086
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.787234	val's rmse: 1.0592
# Early stopping, best iteration is:
# [1482]	train's rmse: 0.714845	val's rmse: 1.05741
# QWK score is 0.43124898343005824
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.787308	val's rmse: 1.04369
# [2000]	train's rmse: 0.654384	val's rmse: 1.04355
# Early stopping, best iteration is:
# [1697]	train's rmse: 0.689868	val's rmse: 1.04228
# QWK score is 0.42205442002619875
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.788743	val's rmse: 1.04542
# [2000]	train's rmse: 0.655148	val's rmse: 1.03974
# Early stopping, best iteration is:
# [1892]	train's rmse: 0.667357	val's rmse: 1.03971
# QWK score is 0.4488612061197642
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.779046	val's rmse: 1.06724
# [2000]	train's rmse: 0.645907	val's rmse: 1.06456
# Early stopping, best iteration is:
# [1690]	train's rmse: 0.681201	val's rmse: 1.06434
# QWK score is 0.4368761040110042
# |  5        |  0.4368   |  0.6976   |  26.68    |  0.6194   |  0.9262   |  98.93    |  10.0     |  74.76    |  0.7279   |  0.8633   |  72.09    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.909818	val's rmse: 1.03623
# [2000]	train's rmse: 0.814741	val's rmse: 1.03356
# [3000]	train's rmse: 0.739561	val's rmse: 1.03336
# Early stopping, best iteration is:
# [2629]	train's rmse: 0.766138	val's rmse: 1.03301
# QWK score is 0.4157833186125769
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.906015	val's rmse: 1.06073
# [2000]	train's rmse: 0.811978	val's rmse: 1.05837
# Early stopping, best iteration is:
# [1711]	train's rmse: 0.836856	val's rmse: 1.05812
# QWK score is 0.44074028081874683
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.905779	val's rmse: 1.04444
# [2000]	train's rmse: 0.811207	val's rmse: 1.04106
# Early stopping, best iteration is:
# [2169]	train's rmse: 0.797428	val's rmse: 1.04094
# QWK score is 0.4243472152955372
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.907126	val's rmse: 1.0477
# [2000]	train's rmse: 0.811685	val's rmse: 1.0414
# [3000]	train's rmse: 0.734801	val's rmse: 1.04051
# Early stopping, best iteration is:
# [3312]	train's rmse: 0.713143	val's rmse: 1.04031
# QWK score is 0.4610319272514397
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.903799	val's rmse: 1.06543
# [2000]	train's rmse: 0.807932	val's rmse: 1.06187
# [3000]	train's rmse: 0.731654	val's rmse: 1.06144
# Early stopping, best iteration is:
# [2642]	train's rmse: 0.757666	val's rmse: 1.06106
# QWK score is 0.45513228271200135
# |  6        |  0.437    |  0.5612   |  1.251    |  0.7587   |  0.2239   |  87.55    |  9.081    |  149.4    |  0.9157   |  0.4764   |  70.18    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.901835	val's rmse: 1.03931
# Early stopping, best iteration is:
# [1213]	train's rmse: 0.878444	val's rmse: 1.03757
# QWK score is 0.4037251217248743
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899071	val's rmse: 1.06064
# [2000]	train's rmse: 0.80395	val's rmse: 1.05879
# Early stopping, best iteration is:
# [1772]	train's rmse: 0.823788	val's rmse: 1.05781
# QWK score is 0.41372301477550344
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.898073	val's rmse: 1.04654
# [2000]	train's rmse: 0.805516	val's rmse: 1.04556
# Early stopping, best iteration is:
# [1548]	train's rmse: 0.84383	val's rmse: 1.04486
# QWK score is 0.4157883073692259
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.898981	val's rmse: 1.05249
# [2000]	train's rmse: 0.802096	val's rmse: 1.04639
# [3000]	train's rmse: 0.723296	val's rmse: 1.04402
# Early stopping, best iteration is:
# [3056]	train's rmse: 0.719982	val's rmse: 1.04384
# QWK score is 0.4565386749843522
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.896622	val's rmse: 1.06542
# [2000]	train's rmse: 0.79854	val's rmse: 1.06068
# [3000]	train's rmse: 0.719048	val's rmse: 1.05998
# Early stopping, best iteration is:
# [2619]	train's rmse: 0.746078	val's rmse: 1.05874
# QWK score is 0.4565457611370167
# |  7        |  0.4339   |  0.6508   |  47.21    |  0.7681   |  0.1656   |  30.95    |  9.008    |  148.5    |  0.6284   |  0.02524  |  71.43    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.904596	val's rmse: 1.03736
# [2000]	train's rmse: 0.800853	val's rmse: 1.03402
# Early stopping, best iteration is:
# [1577]	train's rmse: 0.840847	val's rmse: 1.0338
# QWK score is 0.41937199308800677
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.901007	val's rmse: 1.06163
# [2000]	train's rmse: 0.798625	val's rmse: 1.05827
# [3000]	train's rmse: 0.715457	val's rmse: 1.05746
# Early stopping, best iteration is:
# [2795]	train's rmse: 0.730833	val's rmse: 1.05688
# QWK score is 0.44332256333154485
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900717	val's rmse: 1.04569
# Early stopping, best iteration is:
# [1431]	train's rmse: 0.853161	val's rmse: 1.04351
# QWK score is 0.41262362894082805
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.904223	val's rmse: 1.05007
# [2000]	train's rmse: 0.798064	val's rmse: 1.04371
# [3000]	train's rmse: 0.713415	val's rmse: 1.04166
# [4000]	train's rmse: 0.647164	val's rmse: 1.04019
# Early stopping, best iteration is:
# [3631]	train's rmse: 0.670355	val's rmse: 1.03975
# QWK score is 0.4527175302726616
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899683	val's rmse: 1.06493
# [2000]	train's rmse: 0.792852	val's rmse: 1.06427
# Early stopping, best iteration is:
# [1668]	train's rmse: 0.825825	val's rmse: 1.06221
# QWK score is 0.43676876854396474
# |  8        |  0.4386   |  0.5735   |  49.35    |  0.5298   |  1.541    |  97.6     |  11.7     |  147.9    |  0.2989   |  0.5469   |  71.99    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.879833	val's rmse: 1.03841
# [2000]	train's rmse: 0.783722	val's rmse: 1.03641
# Early stopping, best iteration is:
# [1817]	train's rmse: 0.799413	val's rmse: 1.03604
# QWK score is 0.42873955796592733
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.877728	val's rmse: 1.06244
# [2000]	train's rmse: 0.782945	val's rmse: 1.06019
# Early stopping, best iteration is:
# [2274]	train's rmse: 0.761777	val's rmse: 1.0601
# QWK score is 0.43246243202430557
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.875874	val's rmse: 1.04487
# [2000]	train's rmse: 0.784173	val's rmse: 1.04255
# Early stopping, best iteration is:
# [2447]	train's rmse: 0.749587	val's rmse: 1.04221
# QWK score is 0.4190506070068989
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.878089	val's rmse: 1.04671
# [2000]	train's rmse: 0.782954	val's rmse: 1.04113
# [3000]	train's rmse: 0.708374	val's rmse: 1.03995
# Early stopping, best iteration is:
# [3368]	train's rmse: 0.684287	val's rmse: 1.03975
# QWK score is 0.44655661549420533
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.872627	val's rmse: 1.06684
# [2000]	train's rmse: 0.775172	val's rmse: 1.06434
# Early stopping, best iteration is:
# [1832]	train's rmse: 0.789898	val's rmse: 1.06407
# QWK score is 0.4338361896723122
# |  9        |  0.4371   |  0.8533   |  1.146    |  0.6801   |  0.03938  |  98.48    |  8.87     |  149.0    |  0.0475   |  0.7097   |  74.4     |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.889176	val's rmse: 1.03943
# [2000]	train's rmse: 0.786154	val's rmse: 1.03842
# [3000]	train's rmse: 0.703673	val's rmse: 1.03765
# Early stopping, best iteration is:
# [2680]	train's rmse: 0.727555	val's rmse: 1.03624
# QWK score is 0.4239063540362322
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.886697	val's rmse: 1.06065
# [2000]	train's rmse: 0.786388	val's rmse: 1.05852
# Early stopping, best iteration is:
# [2060]	train's rmse: 0.780917	val's rmse: 1.05831
# QWK score is 0.4415603961541642
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.885874	val's rmse: 1.04784
# Early stopping, best iteration is:
# [1164]	train's rmse: 0.868011	val's rmse: 1.04728
# QWK score is 0.41396112433130816
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.886002	val's rmse: 1.04593
# [2000]	train's rmse: 0.782348	val's rmse: 1.04033
# [3000]	train's rmse: 0.700271	val's rmse: 1.0376
# Early stopping, best iteration is:
# [3129]	train's rmse: 0.690339	val's rmse: 1.03729
# QWK score is 0.46596913871150447
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.881309	val's rmse: 1.06412
# [2000]	train's rmse: 0.78201	val's rmse: 1.06295
# Early stopping, best iteration is:
# [1601]	train's rmse: 0.815443	val's rmse: 1.06177
# QWK score is 0.44680641353305905
# |  10       |  0.4357   |  0.6795   |  44.65    |  0.7077   |  0.07785  |  98.36    |  9.508    |  144.2    |  0.8755   |  0.2143   |  70.77    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.903848	val's rmse: 1.03644
# [2000]	train's rmse: 0.813304	val's rmse: 1.03341
# Early stopping, best iteration is:
# [1888]	train's rmse: 0.822093	val's rmse: 1.03328
# QWK score is 0.4234738698013756
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900955	val's rmse: 1.0609
# [2000]	train's rmse: 0.812206	val's rmse: 1.05776
# Early stopping, best iteration is:
# [2138]	train's rmse: 0.801317	val's rmse: 1.05759
# QWK score is 0.4323143971654875
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899487	val's rmse: 1.0445
# [2000]	train's rmse: 0.811503	val's rmse: 1.04216
# Early stopping, best iteration is:
# [1680]	train's rmse: 0.836861	val's rmse: 1.04196
# QWK score is 0.4274853469630052
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.901158	val's rmse: 1.04814
# [2000]	train's rmse: 0.811655	val's rmse: 1.0412
# [3000]	train's rmse: 0.738994	val's rmse: 1.03958
# [4000]	train's rmse: 0.678368	val's rmse: 1.03979
# Early stopping, best iteration is:
# [3654]	train's rmse: 0.698222	val's rmse: 1.0393
# QWK score is 0.4454147354589927
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.896003	val's rmse: 1.06712
# [2000]	train's rmse: 0.805914	val's rmse: 1.06376
# Early stopping, best iteration is:
# [2181]	train's rmse: 0.791789	val's rmse: 1.06367
# QWK score is 0.43165407400483435
# |  11       |  0.4359   |  0.6924   |  1.805    |  0.5179   |  0.1131   |  99.4     |  8.517    |  149.2    |  0.146    |  0.7205   |  73.69    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.916867	val's rmse: 1.03872
# [2000]	train's rmse: 0.824269	val's rmse: 1.03507
# Early stopping, best iteration is:
# [1793]	train's rmse: 0.841524	val's rmse: 1.03426
# QWK score is 0.42154211875566083
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.912686	val's rmse: 1.06505
# Early stopping, best iteration is:
# [1426]	train's rmse: 0.870424	val's rmse: 1.06141
# QWK score is 0.4201863923965554
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.912786	val's rmse: 1.04596
# [2000]	train's rmse: 0.819747	val's rmse: 1.04419
# Early stopping, best iteration is:
# [1701]	train's rmse: 0.844989	val's rmse: 1.04236
# QWK score is 0.42289736865425
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.915454	val's rmse: 1.04914
# [2000]	train's rmse: 0.822873	val's rmse: 1.045
# [3000]	train's rmse: 0.745322	val's rmse: 1.04346
# Early stopping, best iteration is:
# [2666]	train's rmse: 0.769354	val's rmse: 1.0422
# QWK score is 0.4559455488424812
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.909642	val's rmse: 1.06796
# [2000]	train's rmse: 0.821553	val's rmse: 1.06434
# Early stopping, best iteration is:
# [2037]	train's rmse: 0.818402	val's rmse: 1.06401
# QWK score is 0.43462501025220046
# |  12       |  0.4334   |  0.5489   |  46.47    |  0.7318   |  1.746    |  98.23    |  9.689    |  148.4    |  0.9249   |  0.3646   |  70.4     |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.886667	val's rmse: 1.03785
# [2000]	train's rmse: 0.778738	val's rmse: 1.0355
# [3000]	train's rmse: 0.692027	val's rmse: 1.03498
# Early stopping, best iteration is:
# [2671]	train's rmse: 0.719109	val's rmse: 1.03431
# QWK score is 0.42550922146971226
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.884488	val's rmse: 1.06203
# [2000]	train's rmse: 0.777336	val's rmse: 1.05923
# Early stopping, best iteration is:
# [2066]	train's rmse: 0.771008	val's rmse: 1.05896
# QWK score is 0.4295667922448929
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.882634	val's rmse: 1.04649
# [2000]	train's rmse: 0.776114	val's rmse: 1.04571
# Early stopping, best iteration is:
# [1631]	train's rmse: 0.812169	val's rmse: 1.04488
# QWK score is 0.41876963562745295
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.8859	val's rmse: 1.04593
# [2000]	train's rmse: 0.777903	val's rmse: 1.03853
# Early stopping, best iteration is:
# [2293]	train's rmse: 0.75099	val's rmse: 1.03779
# QWK score is 0.4556534600068902
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.881112	val's rmse: 1.06581
# [2000]	train's rmse: 0.771087	val's rmse: 1.06392
# Early stopping, best iteration is:
# [1545]	train's rmse: 0.8167	val's rmse: 1.06336
# QWK score is 0.44413137840852823
# |  13       |  0.4389   |  0.6767   |  4.168    |  0.82     |  1.284    |  35.14    |  10.65    |  149.6    |  0.1562   |  0.2246   |  70.12    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.91626	val's rmse: 1.03796
# [2000]	train's rmse: 0.81728	val's rmse: 1.0349
# Early stopping, best iteration is:
# [1861]	train's rmse: 0.829626	val's rmse: 1.03443
# QWK score is 0.4197324317842399
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.911986	val's rmse: 1.06011
# [2000]	train's rmse: 0.813184	val's rmse: 1.05764
# Early stopping, best iteration is:
# [1680]	train's rmse: 0.841808	val's rmse: 1.05706
# QWK score is 0.450096742002
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.911821	val's rmse: 1.04435
# [2000]	train's rmse: 0.812932	val's rmse: 1.04171
# Early stopping, best iteration is:
# [2083]	train's rmse: 0.805988	val's rmse: 1.0415
# QWK score is 0.4253331897708048
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.914138	val's rmse: 1.04984
# [2000]	train's rmse: 0.814854	val's rmse: 1.04233
# [3000]	train's rmse: 0.737442	val's rmse: 1.04257
# Early stopping, best iteration is:
# [2549]	train's rmse: 0.770261	val's rmse: 1.04211
# QWK score is 0.44618125439291123
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.911057	val's rmse: 1.06796
# [2000]	train's rmse: 0.812699	val's rmse: 1.06333
# [3000]	train's rmse: 0.735135	val's rmse: 1.0632
# Early stopping, best iteration is:
# [2721]	train's rmse: 0.755109	val's rmse: 1.06261
# QWK score is 0.44818795269557177
# |  14       |  0.4402   |  0.5116   |  1.738    |  0.7734   |  1.539    |  38.36    |  11.21    |  148.2    |  0.09495  |  0.6762   |  71.11    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.741915	val's rmse: 1.03353
# [2000]	train's rmse: 0.579671	val's rmse: 1.03193
# Early stopping, best iteration is:
# [1640]	train's rmse: 0.625719	val's rmse: 1.03159
# QWK score is 0.43133076161531436
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.737736	val's rmse: 1.06163
# [2000]	train's rmse: 0.575439	val's rmse: 1.06028
# Early stopping, best iteration is:
# [1763]	train's rmse: 0.604032	val's rmse: 1.06006
# QWK score is 0.42486922531654747
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.739029	val's rmse: 1.0451
# Early stopping, best iteration is:
# [1157]	train's rmse: 0.707127	val's rmse: 1.04459
# QWK score is 0.4170900191841592
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.739677	val's rmse: 1.04721
# [2000]	train's rmse: 0.577123	val's rmse: 1.04269
# [3000]	train's rmse: 0.514349	val's rmse: 1.04181
# [4000]	train's rmse: 0.49372	val's rmse: 1.04114
# Early stopping, best iteration is:
# [4401]	train's rmse: 0.488918	val's rmse: 1.04089
# QWK score is 0.4533671625492135
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.736802	val's rmse: 1.06333
# Early stopping, best iteration is:
# [1482]	train's rmse: 0.644534	val's rmse: 1.06286
# QWK score is 0.4316050302959836
# |  15       |  0.4381   |  0.7618   |  2.37     |  0.6815   |  0.4068   |  30.32    |  11.68    |  38.69    |  0.09656  |  0.7889   |  72.7     |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.859902	val's rmse: 1.03878
# [2000]	train's rmse: 0.743669	val's rmse: 1.03556
# Early stopping, best iteration is:
# [1895]	train's rmse: 0.754261	val's rmse: 1.03523
# QWK score is 0.41101284800249815
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.856435	val's rmse: 1.0628
# [2000]	train's rmse: 0.739701	val's rmse: 1.05995
# Early stopping, best iteration is:
# [2032]	train's rmse: 0.736631	val's rmse: 1.05985
# QWK score is 0.41611840135289646
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.856889	val's rmse: 1.04622
# [2000]	train's rmse: 0.744875	val's rmse: 1.04496
# Early stopping, best iteration is:
# [1607]	train's rmse: 0.785723	val's rmse: 1.04486
# QWK score is 0.42737719225772275
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.858108	val's rmse: 1.04531
# [2000]	train's rmse: 0.743513	val's rmse: 1.04003
# [3000]	train's rmse: 0.654723	val's rmse: 1.03879
# Early stopping, best iteration is:
# [3249]	train's rmse: 0.635682	val's rmse: 1.03843
# QWK score is 0.45457035919519706
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.853383	val's rmse: 1.06707
# Early stopping, best iteration is:
# [1446]	train's rmse: 0.795515	val's rmse: 1.06559
# QWK score is 0.425045750964838
# |  16       |  0.4361   |  0.8669   |  4.132    |  0.6673   |  0.7858   |  33.18    |  10.43    |  149.0    |  0.9826   |  0.4335   |  70.12    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.845505	val's rmse: 1.03656
# Early stopping, best iteration is:
# [1369]	train's rmse: 0.79163	val's rmse: 1.03534
# QWK score is 0.42488863579057856
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.84241	val's rmse: 1.06067
# [2000]	train's rmse: 0.711868	val's rmse: 1.05854
# Early stopping, best iteration is:
# [1690]	train's rmse: 0.748238	val's rmse: 1.05824
# QWK score is 0.44050511737177867
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.841569	val's rmse: 1.04334
# Early stopping, best iteration is:
# [1314]	train's rmse: 0.796248	val's rmse: 1.04217
# QWK score is 0.4233977227573439
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843734	val's rmse: 1.04382
# [2000]	train's rmse: 0.712024	val's rmse: 1.03836
# [3000]	train's rmse: 0.609925	val's rmse: 1.03794
# Early stopping, best iteration is:
# [2745]	train's rmse: 0.63365	val's rmse: 1.03765
# QWK score is 0.44418082007423687
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.840116	val's rmse: 1.06594
# [2000]	train's rmse: 0.706871	val's rmse: 1.06413
# Early stopping, best iteration is:
# [1945]	train's rmse: 0.71329	val's rmse: 1.06391
# QWK score is 0.4476368619907457
# |  17       |  0.4379   |  0.582    |  1.604    |  0.7596   |  0.7878   |  56.12    |  11.94    |  102.6    |  0.09769  |  0.4446   |  72.01    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.740575	val's rmse: 1.03679
# [2000]	train's rmse: 0.553462	val's rmse: 1.03484
# Early stopping, best iteration is:
# [2146]	train's rmse: 0.531942	val's rmse: 1.0342
# QWK score is 0.40768871965248543
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.737135	val's rmse: 1.06228
# [2000]	train's rmse: 0.551785	val's rmse: 1.06088
# Early stopping, best iteration is:
# [1660]	train's rmse: 0.606882	val's rmse: 1.06029
# QWK score is 0.41789404292394383
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.736915	val's rmse: 1.04381
# Early stopping, best iteration is:
# [1180]	train's rmse: 0.698225	val's rmse: 1.043
# QWK score is 0.4218910032447516
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.739514	val's rmse: 1.05139
# [2000]	train's rmse: 0.552758	val's rmse: 1.04791
# [3000]	train's rmse: 0.42497	val's rmse: 1.04731
# Early stopping, best iteration is:
# [3224]	train's rmse: 0.402136	val's rmse: 1.04697
# QWK score is 0.44318924533224924
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.736223	val's rmse: 1.06481
# [2000]	train's rmse: 0.549903	val's rmse: 1.0634
# Early stopping, best iteration is:
# [1615]	train's rmse: 0.612321	val's rmse: 1.06266
# QWK score is 0.4383940567906417
# |  18       |  0.4372   |  0.8092   |  5.344    |  0.8171   |  1.212    |  30.06    |  10.97    |  33.21    |  0.9733   |  0.1874   |  70.1     |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.883109	val's rmse: 1.03679
# [2000]	train's rmse: 0.769903	val's rmse: 1.03445
# Early stopping, best iteration is:
# [2295]	train's rmse: 0.742215	val's rmse: 1.03417
# QWK score is 0.414075661599443
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.880362	val's rmse: 1.06
# [2000]	train's rmse: 0.767671	val's rmse: 1.05755
# Early stopping, best iteration is:
# [2054]	train's rmse: 0.762379	val's rmse: 1.0573
# QWK score is 0.4450829818440588
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.880021	val's rmse: 1.04454
# Early stopping, best iteration is:
# [1420]	train's rmse: 0.82882	val's rmse: 1.04247
# QWK score is 0.4220722051699687
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.881432	val's rmse: 1.04645
# [2000]	train's rmse: 0.768416	val's rmse: 1.0401
# [3000]	train's rmse: 0.679634	val's rmse: 1.03941
# [4000]	train's rmse: 0.608957	val's rmse: 1.0391
# [5000]	train's rmse: 0.552509	val's rmse: 1.03949
# Early stopping, best iteration is:
# [4521]	train's rmse: 0.577555	val's rmse: 1.03871
# QWK score is 0.4662900865668599
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.877927	val's rmse: 1.06636
# [2000]	train's rmse: 0.763519	val's rmse: 1.06367
# Early stopping, best iteration is:
# [1916]	train's rmse: 0.771922	val's rmse: 1.06329
# QWK score is 0.44048977247556365
# |  19       |  0.4374   |  0.6812   |  3.116    |  0.6226   |  0.4469   |  34.67    |  11.65    |  147.3    |  0.5812   |  0.4871   |  70.25    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.903562	val's rmse: 1.03606
# [2000]	train's rmse: 0.798912	val's rmse: 1.0338
# [3000]	train's rmse: 0.718345	val's rmse: 1.03292
# Early stopping, best iteration is:
# [2732]	train's rmse: 0.738318	val's rmse: 1.03258
# QWK score is 0.42908057245225795
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900638	val's rmse: 1.06249
# [2000]	train's rmse: 0.796015	val's rmse: 1.06034
# Early stopping, best iteration is:
# [2164]	train's rmse: 0.781535	val's rmse: 1.05996
# QWK score is 0.4391127337586511
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899313	val's rmse: 1.04399
# [2000]	train's rmse: 0.795932	val's rmse: 1.04178
# Early stopping, best iteration is:
# [2240]	train's rmse: 0.774718	val's rmse: 1.04158
# QWK score is 0.42632979376363245
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.902878	val's rmse: 1.0496
# [2000]	train's rmse: 0.798236	val's rmse: 1.04195
# Early stopping, best iteration is:
# [2071]	train's rmse: 0.791752	val's rmse: 1.04167
# QWK score is 0.4384070079151364
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.898904	val's rmse: 1.06673
# [2000]	train's rmse: 0.795351	val's rmse: 1.06415
# Early stopping, best iteration is:
# [2226]	train's rmse: 0.77509	val's rmse: 1.06354
# QWK score is 0.45443061264767426
# |  20       |  0.4381   |  0.5267   |  4.433    |  0.7633   |  0.2527   |  30.37    |  11.45    |  136.9    |  0.1977   |  0.6849   |  70.57    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.88854	val's rmse: 1.03792
# [2000]	train's rmse: 0.781962	val's rmse: 1.03475
# Early stopping, best iteration is:
# [2380]	train's rmse: 0.748022	val's rmse: 1.03419
# QWK score is 0.42215017854663406
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.885613	val's rmse: 1.06156
# [2000]	train's rmse: 0.778818	val's rmse: 1.05871
# Early stopping, best iteration is:
# [2290]	train's rmse: 0.753513	val's rmse: 1.05832
# QWK score is 0.43104415184956635
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.885388	val's rmse: 1.04466
# [2000]	train's rmse: 0.78011	val's rmse: 1.04334
# Early stopping, best iteration is:
# [1551]	train's rmse: 0.824347	val's rmse: 1.04279
# QWK score is 0.42166038456787125
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.887372	val's rmse: 1.04743
# [2000]	train's rmse: 0.780778	val's rmse: 1.04066
# [3000]	train's rmse: 0.697121	val's rmse: 1.03955
# Early stopping, best iteration is:
# [2861]	train's rmse: 0.707823	val's rmse: 1.03921
# QWK score is 0.44399147792871996
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.882607	val's rmse: 1.06623
# [2000]	train's rmse: 0.774629	val's rmse: 1.06373
# [3000]	train's rmse: 0.69107	val's rmse: 1.06353
# Early stopping, best iteration is:
# [2699]	train's rmse: 0.714629	val's rmse: 1.06311
# QWK score is 0.441228323205875
# |  21       |  0.4363   |  0.6254   |  1.781    |  0.8433   |  1.423    |  33.21    |  10.28    |  140.9    |  0.5867   |  0.644    |  70.62    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.745115	val's rmse: 1.0372
# [2000]	train's rmse: 0.572942	val's rmse: 1.03343
# Early stopping, best iteration is:
# [2245]	train's rmse: 0.543112	val's rmse: 1.03304
# QWK score is 0.43724607032218854
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.740616	val's rmse: 1.06231
# [2000]	train's rmse: 0.570252	val's rmse: 1.06202
# Early stopping, best iteration is:
# [1622]	train's rmse: 0.623863	val's rmse: 1.06106
# QWK score is 0.43895346815847636
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.741642	val's rmse: 1.04509
# [2000]	train's rmse: 0.57182	val's rmse: 1.04414
# Early stopping, best iteration is:
# [1595]	train's rmse: 0.630539	val's rmse: 1.04389
# QWK score is 0.4232280522599837
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.743366	val's rmse: 1.04486
# [2000]	train's rmse: 0.570368	val's rmse: 1.04074
# [3000]	train's rmse: 0.476555	val's rmse: 1.03877
# [4000]	train's rmse: 0.441645	val's rmse: 1.03834
# Early stopping, best iteration is:
# [4456]	train's rmse: 0.433274	val's rmse: 1.03818
# QWK score is 0.45483539031199804
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.740085	val's rmse: 1.06352
# [2000]	train's rmse: 0.567508	val's rmse: 1.06348
# Early stopping, best iteration is:
# [1565]	train's rmse: 0.631537	val's rmse: 1.0622
# QWK score is 0.4297376142404927
# |  22       |  0.4364   |  0.6812   |  2.001    |  0.7373   |  0.2995   |  31.49    |  10.71    |  31.2     |  0.2865   |  0.6394   |  70.97    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.923966	val's rmse: 1.03615
# [2000]	train's rmse: 0.839104	val's rmse: 1.03289
# [3000]	train's rmse: 0.771996	val's rmse: 1.03314
# Early stopping, best iteration is:
# [2544]	train's rmse: 0.801434	val's rmse: 1.03217
# QWK score is 0.4306108281101284
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.921125	val's rmse: 1.06119
# [2000]	train's rmse: 0.836419	val's rmse: 1.05785
# Early stopping, best iteration is:
# [1898]	train's rmse: 0.844208	val's rmse: 1.05761
# QWK score is 0.44592580254063974
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.919566	val's rmse: 1.04449
# [2000]	train's rmse: 0.835523	val's rmse: 1.0406
# Early stopping, best iteration is:
# [2313]	train's rmse: 0.812639	val's rmse: 1.0403
# QWK score is 0.41215841578437373
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.920911	val's rmse: 1.04921
# [2000]	train's rmse: 0.835569	val's rmse: 1.04067
# [3000]	train's rmse: 0.767887	val's rmse: 1.03946
# Early stopping, best iteration is:
# [2703]	train's rmse: 0.786195	val's rmse: 1.03918
# QWK score is 0.4461216274889874
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.918055	val's rmse: 1.0664
# [2000]	train's rmse: 0.832841	val's rmse: 1.062
# [3000]	train's rmse: 0.764177	val's rmse: 1.06183
# Early stopping, best iteration is:
# [2694]	train's rmse: 0.784173	val's rmse: 1.06123
# QWK score is 0.442998810819467
# |  23       |  0.4393   |  0.58     |  1.352    |  0.5225   |  1.279    |  38.18    |  8.748    |  150.0    |  0.1482   |  0.5373   |  70.75    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.903536	val's rmse: 1.03643
# [2000]	train's rmse: 0.800097	val's rmse: 1.03286
# Early stopping, best iteration is:
# [2048]	train's rmse: 0.795936	val's rmse: 1.0328
# QWK score is 0.4150270562250008
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899182	val's rmse: 1.06238
# [2000]	train's rmse: 0.795802	val's rmse: 1.05922
# Early stopping, best iteration is:
# [2280]	train's rmse: 0.771893	val's rmse: 1.05893
# QWK score is 0.43722816796536446
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899728	val's rmse: 1.04594
# Early stopping, best iteration is:
# [1498]	train's rmse: 0.844282	val's rmse: 1.04273
# QWK score is 0.4145173389306501
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.901284	val's rmse: 1.04878
# [2000]	train's rmse: 0.797563	val's rmse: 1.04212
# Early stopping, best iteration is:
# [2243]	train's rmse: 0.777148	val's rmse: 1.04169
# QWK score is 0.446303769039459
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.898313	val's rmse: 1.06554
# [2000]	train's rmse: 0.795678	val's rmse: 1.06187
# [3000]	train's rmse: 0.717152	val's rmse: 1.06234
# Early stopping, best iteration is:
# [2507]	train's rmse: 0.753644	val's rmse: 1.06164
# QWK score is 0.4441945412864412
# |  24       |  0.4377   |  0.5344   |  1.654    |  0.8421   |  0.1645   |  30.37    |  11.15    |  139.3    |  0.3866   |  0.8257   |  70.36    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.868995	val's rmse: 1.03815
# [2000]	train's rmse: 0.747937	val's rmse: 1.03539
# Early stopping, best iteration is:
# [1648]	train's rmse: 0.786599	val's rmse: 1.035
# QWK score is 0.41816912119894634
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.864677	val's rmse: 1.06263
# [2000]	train's rmse: 0.745109	val's rmse: 1.06094
# Early stopping, best iteration is:
# [1542]	train's rmse: 0.794841	val's rmse: 1.06083
# QWK score is 0.42901737828252673
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.864504	val's rmse: 1.04535
# [2000]	train's rmse: 0.746535	val's rmse: 1.04356
# Early stopping, best iteration is:
# [1682]	train's rmse: 0.780778	val's rmse: 1.04294
# QWK score is 0.42350707684785305
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.866755	val's rmse: 1.04497
# [2000]	train's rmse: 0.746344	val's rmse: 1.03958
# Early stopping, best iteration is:
# [2226]	train's rmse: 0.723003	val's rmse: 1.03902
# QWK score is 0.4514845846737304
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.862315	val's rmse: 1.06694
# [2000]	train's rmse: 0.741856	val's rmse: 1.06383
# Early stopping, best iteration is:
# [1841]	train's rmse: 0.759317	val's rmse: 1.06366
# QWK score is 0.4373023077029059
# |  25       |  0.4365   |  0.7678   |  2.324    |  0.6605   |  1.22     |  34.36    |  11.92    |  148.7    |  0.4442   |  0.2178   |  71.34    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.892267	val's rmse: 1.0389
# [2000]	train's rmse: 0.799776	val's rmse: 1.03612
# Early stopping, best iteration is:
# [1852]	train's rmse: 0.811619	val's rmse: 1.03565
# QWK score is 0.4250877284170299
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.887887	val's rmse: 1.0632
# [2000]	train's rmse: 0.796885	val's rmse: 1.05933
# Early stopping, best iteration is:
# [2259]	train's rmse: 0.777527	val's rmse: 1.05879
# QWK score is 0.4290244096103115
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.887401	val's rmse: 1.04516
# [2000]	train's rmse: 0.798658	val's rmse: 1.04303
# Early stopping, best iteration is:
# [1664]	train's rmse: 0.826106	val's rmse: 1.04269
# QWK score is 0.41989222784025915
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.888195	val's rmse: 1.04698
# [2000]	train's rmse: 0.797431	val's rmse: 1.04108
# [3000]	train's rmse: 0.7307	val's rmse: 1.03973
# Early stopping, best iteration is:
# [3157]	train's rmse: 0.721569	val's rmse: 1.03951
# QWK score is 0.4671990288168296
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.884779	val's rmse: 1.06684
# [2000]	train's rmse: 0.793692	val's rmse: 1.06388
# Early stopping, best iteration is:
# [2184]	train's rmse: 0.779535	val's rmse: 1.06342
# QWK score is 0.43430131801723815
# |  26       |  0.4382   |  0.806    |  1.496    |  0.6828   |  0.7752   |  30.68    |  8.672    |  148.4    |  0.56     |  0.9749   |  72.84    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.848924	val's rmse: 1.03635
# [2000]	train's rmse: 0.726977	val's rmse: 1.03428
# Early stopping, best iteration is:
# [2430]	train's rmse: 0.687154	val's rmse: 1.03399
# QWK score is 0.41906093748277706
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.845088	val's rmse: 1.06228
# [2000]	train's rmse: 0.724594	val's rmse: 1.06073
# Early stopping, best iteration is:
# [1817]	train's rmse: 0.743129	val's rmse: 1.06029
# QWK score is 0.42189139740951864
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.845161	val's rmse: 1.04623
# Early stopping, best iteration is:
# [1270]	train's rmse: 0.808559	val's rmse: 1.04487
# QWK score is 0.41926107009541014
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.846643	val's rmse: 1.04441
# [2000]	train's rmse: 0.725065	val's rmse: 1.04002
# [3000]	train's rmse: 0.643883	val's rmse: 1.03888
# [4000]	train's rmse: 0.592842	val's rmse: 1.0386
# Early stopping, best iteration is:
# [3747]	train's rmse: 0.603562	val's rmse: 1.03834
# QWK score is 0.4479283901002695
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843355	val's rmse: 1.06663
# [2000]	train's rmse: 0.723127	val's rmse: 1.06377
# Early stopping, best iteration is:
# [2085]	train's rmse: 0.714657	val's rmse: 1.06368
# QWK score is 0.4484408284538587
# |  27       |  0.437    |  0.8164   |  2.57     |  0.7335   |  0.4972   |  31.2     |  11.5     |  138.6    |  0.4622   |  0.7776   |  70.0     |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.873642	val's rmse: 1.03678
# [2000]	train's rmse: 0.756121	val's rmse: 1.03406
# Early stopping, best iteration is:
# [2223]	train's rmse: 0.733649	val's rmse: 1.03387
# QWK score is 0.4294541990861619
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.870875	val's rmse: 1.06107
# [2000]	train's rmse: 0.752895	val's rmse: 1.05804
# Early stopping, best iteration is:
# [1979]	train's rmse: 0.754941	val's rmse: 1.05802
# QWK score is 0.42872869498981214
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.870397	val's rmse: 1.04462
# [2000]	train's rmse: 0.7544	val's rmse: 1.04287
# Early stopping, best iteration is:
# [2304]	train's rmse: 0.724691	val's rmse: 1.04256
# QWK score is 0.4273181753851527
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.87175	val's rmse: 1.04537
# [2000]	train's rmse: 0.753947	val's rmse: 1.03852
# [3000]	train's rmse: 0.660373	val's rmse: 1.03673
# Early stopping, best iteration is:
# [2707]	train's rmse: 0.685433	val's rmse: 1.03643
# QWK score is 0.45402944464024786
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.86744	val's rmse: 1.06634
# [2000]	train's rmse: 0.748624	val's rmse: 1.06262
# Early stopping, best iteration is:
# [2069]	train's rmse: 0.741717	val's rmse: 1.06236
# QWK score is 0.4471896748397426
# |  28       |  0.4421   |  0.7171   |  1.723    |  0.5043   |  1.44     |  97.91    |  11.16    |  146.8    |  0.6213   |  0.1931   |  70.07    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.846586	val's rmse: 1.03681
# [2000]	train's rmse: 0.719572	val's rmse: 1.03429
# Early stopping, best iteration is:
# [1820]	train's rmse: 0.739626	val's rmse: 1.03395
# QWK score is 0.42386225965096946
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.844553	val's rmse: 1.06148
# [2000]	train's rmse: 0.718165	val's rmse: 1.05984
# Early stopping, best iteration is:
# [2236]	train's rmse: 0.693089	val's rmse: 1.0594
# QWK score is 0.43949269179119665
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.842239	val's rmse: 1.04613
# [2000]	train's rmse: 0.718023	val's rmse: 1.04508
# Early stopping, best iteration is:
# [1682]	train's rmse: 0.75394	val's rmse: 1.04448
# QWK score is 0.40848159742640067
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843571	val's rmse: 1.04427
# [2000]	train's rmse: 0.716558	val's rmse: 1.03841
# Early stopping, best iteration is:
# [2292]	train's rmse: 0.685399	val's rmse: 1.03799
# QWK score is 0.4545378233737052
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.839534	val's rmse: 1.06531
# [2000]	train's rmse: 0.711953	val's rmse: 1.06343
# Early stopping, best iteration is:
# [1655]	train's rmse: 0.7518	val's rmse: 1.06325
# QWK score is 0.4384767518985595
# |  29       |  0.4395   |  0.7647   |  3.645    |  0.7327   |  1.028    |  98.35    |  12.0     |  135.8    |  0.8972   |  0.5002   |  70.12    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.884822	val's rmse: 1.03709
# [2000]	train's rmse: 0.782828	val's rmse: 1.03373
# Early stopping, best iteration is:
# [2079]	train's rmse: 0.775722	val's rmse: 1.03336
# QWK score is 0.4104379025414069
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.882719	val's rmse: 1.05996
# [2000]	train's rmse: 0.780638	val's rmse: 1.05658
# Early stopping, best iteration is:
# [2127]	train's rmse: 0.768969	val's rmse: 1.05645
# QWK score is 0.4446253385637544
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.88149	val's rmse: 1.04369
# [2000]	train's rmse: 0.780754	val's rmse: 1.04143
# Early stopping, best iteration is:
# [1686]	train's rmse: 0.809862	val's rmse: 1.04114
# QWK score is 0.4254212831555798
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.88243	val's rmse: 1.0466
# [2000]	train's rmse: 0.779682	val's rmse: 1.03982
# [3000]	train's rmse: 0.69558	val's rmse: 1.03861
# Early stopping, best iteration is:
# [3117]	train's rmse: 0.68681	val's rmse: 1.03839
# QWK score is 0.46097621303401337
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.877326	val's rmse: 1.06632
# [2000]	train's rmse: 0.774318	val's rmse: 1.06364
# Early stopping, best iteration is:
# [2166]	train's rmse: 0.759202	val's rmse: 1.06321
# QWK score is 0.4392953711653712
# |  30       |  0.4375   |  0.7026   |  1.106    |  0.5635   |  1.884    |  99.02    |  9.803    |  142.3    |  0.9466   |  0.09109  |  70.35    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.893129	val's rmse: 1.03745
# [2000]	train's rmse: 0.78509	val's rmse: 1.03566
# ...
# [2000]	train's rmse: 0.717532	val's rmse: 1.03503
# Early stopping, best iteration is:
# [2087]	train's rmse: 0.70806	val's rmse: 1.03486
# QWK score is 0.43185345929255725
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.840925	val's rmse: 1.06159
# [2000]	train's rmse: 0.713591	val's rmse: 1.05982
# Early stopping, best iteration is:
# [1665]	train's rmse: 0.752189	val's rmse: 1.05935
# QWK score is 0.43807401251357647
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.842518	val's rmse: 1.04521
# Early stopping, best iteration is:
# [1307]	train's rmse: 0.799891	val's rmse: 1.04386
# QWK score is 0.4180206082843113
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843713	val's rmse: 1.04463
# [2000]	train's rmse: 0.715228	val's rmse: 1.03934
# Early stopping, best iteration is:
# [2225]	train's rmse: 0.690778	val's rmse: 1.03906
# QWK score is 0.4641003097697811
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.838968	val's rmse: 1.0659
# [2000]	train's rmse: 0.708905	val's rmse: 1.06473
# Early stopping, best iteration is:
# [1555]	train's rmse: 0.7607	val's rmse: 1.0638
# QWK score is 0.4436587823238757
# |  46       |  0.4379   |  0.7682   |  1.777    |  0.8351   |  0.7132   |  92.69    |  11.38    |  137.5    |  0.1525   |  0.2719   |  70.29    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.902692	val's rmse: 1.03579
# [2000]	train's rmse: 0.801025	val's rmse: 1.03264
# Early stopping, best iteration is:
# [2193]	train's rmse: 0.784593	val's rmse: 1.03243
# QWK score is 0.4330386262033553
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.89946	val's rmse: 1.06043
# [2000]	train's rmse: 0.79822	val's rmse: 1.05691
# Early stopping, best iteration is:
# [1949]	train's rmse: 0.802912	val's rmse: 1.05669
# QWK score is 0.4457938971562657
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899178	val's rmse: 1.04554
# [2000]	train's rmse: 0.797083	val's rmse: 1.04258
# Early stopping, best iteration is:
# [2114]	train's rmse: 0.786713	val's rmse: 1.04228
# QWK score is 0.428689220685772
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900997	val's rmse: 1.04819
# [2000]	train's rmse: 0.798522	val's rmse: 1.04092
# [3000]	train's rmse: 0.719425	val's rmse: 1.04069
# Early stopping, best iteration is:
# [2507]	train's rmse: 0.756378	val's rmse: 1.04009
# QWK score is 0.4657766950303187
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.897362	val's rmse: 1.06536
# [2000]	train's rmse: 0.794994	val's rmse: 1.06289
# Early stopping, best iteration is:
# [2019]	train's rmse: 0.793334	val's rmse: 1.06262
# QWK score is 0.4393688330401021
# |  47       |  0.4413   |  0.58     |  1.165    |  0.6117   |  1.669    |  94.41    |  10.84    |  147.6    |  0.3913   |  0.7323   |  70.26    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.904349	val's rmse: 1.03775
# [2000]	train's rmse: 0.798021	val's rmse: 1.03584
# Early stopping, best iteration is:
# [2001]	train's rmse: 0.797932	val's rmse: 1.0358
# QWK score is 0.4169410415582845
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900738	val's rmse: 1.06122
# [2000]	train's rmse: 0.794857	val's rmse: 1.0591
# Early stopping, best iteration is:
# [1665]	train's rmse: 0.827197	val's rmse: 1.05886
# QWK score is 0.4386495143947059
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.900425	val's rmse: 1.04354
# [2000]	train's rmse: 0.795825	val's rmse: 1.04159
# Early stopping, best iteration is:
# [1676]	train's rmse: 0.826838	val's rmse: 1.0414
# QWK score is 0.4283477795198811
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.902226	val's rmse: 1.04802
# [2000]	train's rmse: 0.796087	val's rmse: 1.04137
# [3000]	train's rmse: 0.711619	val's rmse: 1.0407
# Early stopping, best iteration is:
# [2879]	train's rmse: 0.721062	val's rmse: 1.04046
# QWK score is 0.4469704297856182
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.899868	val's rmse: 1.06541
# [2000]	train's rmse: 0.794539	val's rmse: 1.06319
# Early stopping, best iteration is:
# [2034]	train's rmse: 0.791319	val's rmse: 1.06297
# QWK score is 0.43496727899407184
# |  48       |  0.4366   |  0.5145   |  1.29     |  0.7563   |  0.6202   |  93.39    |  11.55    |  142.0    |  0.8968   |  0.3989   |  71.01    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.910513	val's rmse: 1.03669
# [2000]	train's rmse: 0.808974	val's rmse: 1.03379
# Early stopping, best iteration is:
# [2330]	train's rmse: 0.781071	val's rmse: 1.03306
# QWK score is 0.41121344158115203
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.90724	val's rmse: 1.06128
# [2000]	train's rmse: 0.805792	val's rmse: 1.05878
# Early stopping, best iteration is:
# [2233]	train's rmse: 0.786058	val's rmse: 1.05817
# QWK score is 0.4241658831541055
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.907039	val's rmse: 1.04351
# [2000]	train's rmse: 0.805168	val's rmse: 1.04015
# Early stopping, best iteration is:
# [2175]	train's rmse: 0.790177	val's rmse: 1.03984
# QWK score is 0.4113346323424554
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.90935	val's rmse: 1.0484
# [2000]	train's rmse: 0.807002	val's rmse: 1.04172
# [3000]	train's rmse: 0.727242	val's rmse: 1.04064
# Early stopping, best iteration is:
# [2980]	train's rmse: 0.72872	val's rmse: 1.04041
# QWK score is 0.4615391886909913
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.906325	val's rmse: 1.06659
# [2000]	train's rmse: 0.804691	val's rmse: 1.06491
# Early stopping, best iteration is:
# [1681]	train's rmse: 0.833752	val's rmse: 1.06392
# QWK score is 0.43306197139172553
# |  49       |  0.4375   |  0.517    |  3.287    |  0.6922   |  1.108    |  95.88    |  11.87    |  147.1    |  0.02576  |  0.7171   |  70.72    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.884116	val's rmse: 1.03724
# [2000]	train's rmse: 0.769397	val's rmse: 1.03471
# [3000]	train's rmse: 0.678125	val's rmse: 1.03466
# Early stopping, best iteration is:
# [2521]	train's rmse: 0.719646	val's rmse: 1.03359
# QWK score is 0.4182681407327725
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.880115	val's rmse: 1.06038
# [2000]	train's rmse: 0.765232	val's rmse: 1.05854
# Early stopping, best iteration is:
# [1654]	train's rmse: 0.801409	val's rmse: 1.05836
# QWK score is 0.4422818576638571
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.879932	val's rmse: 1.04471
# [2000]	train's rmse: 0.766447	val's rmse: 1.04401
# Early stopping, best iteration is:
# [1517]	train's rmse: 0.817609	val's rmse: 1.04345
# QWK score is 0.42026278147950535
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.881959	val's rmse: 1.04582
# [2000]	train's rmse: 0.766658	val's rmse: 1.04028
# [3000]	train's rmse: 0.675265	val's rmse: 1.04016
# Early stopping, best iteration is:
# [2564]	train's rmse: 0.713043	val's rmse: 1.03956
# QWK score is 0.4496820938869176
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.878274	val's rmse: 1.06535
# [2000]	train's rmse: 0.76164	val's rmse: 1.06095
# Early stopping, best iteration is:
# [1971]	train's rmse: 0.764485	val's rmse: 1.06086
# QWK score is 0.45938926341289754
# |  50       |  0.4381   |  0.6124   |  1.153    |  0.6734   |  1.201    |  93.79    |  11.64    |  140.9    |  0.1361   |  0.004105 |  70.88    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.889615	val's rmse: 1.03697
# [2000]	train's rmse: 0.778082	val's rmse: 1.03468
# Early stopping, best iteration is:
# [1740]	train's rmse: 0.804014	val's rmse: 1.03453
# QWK score is 0.40933348726094454
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.886128	val's rmse: 1.06059
# [2000]	train's rmse: 0.774986	val's rmse: 1.05812
# Early stopping, best iteration is:
# [1823]	train's rmse: 0.792406	val's rmse: 1.05793
# QWK score is 0.4401593907524215
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.88652	val's rmse: 1.04508
# [2000]	train's rmse: 0.775663	val's rmse: 1.04259
# Early stopping, best iteration is:
# [2017]	train's rmse: 0.773858	val's rmse: 1.04246
# QWK score is 0.42566302440497106
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.888231	val's rmse: 1.04664
# [2000]	train's rmse: 0.776754	val's rmse: 1.03935
# [3000]	train's rmse: 0.687794	val's rmse: 1.03856
# Early stopping, best iteration is:
# [3021]	train's rmse: 0.686023	val's rmse: 1.03843
# QWK score is 0.45083964993748893
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.883825	val's rmse: 1.06642
# [2000]	train's rmse: 0.772364	val's rmse: 1.06362
# Early stopping, best iteration is:
# [1936]	train's rmse: 0.778721	val's rmse: 1.06344
# QWK score is 0.4460103585511126
# |  51       |  0.438    |  0.595    |  1.085    |  0.8007   |  0.2832   |  99.51    |  11.58    |  147.4    |  0.002706 |  0.2103   |  71.57    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.845962	val's rmse: 1.03719
# [2000]	train's rmse: 0.72748	val's rmse: 1.0352
# Early stopping, best iteration is:
# [2288]	train's rmse: 0.701439	val's rmse: 1.03502
# QWK score is 0.4272337768749247
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843672	val's rmse: 1.05929
# [2000]	train's rmse: 0.724761	val's rmse: 1.05656
# Early stopping, best iteration is:
# [2290]	train's rmse: 0.698977	val's rmse: 1.05619
# QWK score is 0.4415769338439016
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.843683	val's rmse: 1.04571
# [2000]	train's rmse: 0.728419	val's rmse: 1.0448
# Early stopping, best iteration is:
# [1514]	train's rmse: 0.778874	val's rmse: 1.04438
# QWK score is 0.4179129504529794
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.844634	val's rmse: 1.04549
# [2000]	train's rmse: 0.725989	val's rmse: 1.04016
# [3000]	train's rmse: 0.650812	val's rmse: 1.03956
# [4000]	train's rmse: 0.613707	val's rmse: 1.03879
# Early stopping, best iteration is:
# [4296]	train's rmse: 0.607256	val's rmse: 1.03859
# QWK score is 0.45541443734075526
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.839365	val's rmse: 1.06713
# Early stopping, best iteration is:
# [1457]	train's rmse: 0.778123	val's rmse: 1.06516
# QWK score is 0.450031778035038
# |  52       |  0.437    |  0.8927   |  2.415    |  0.5337   |  0.8956   |  86.96    |  11.72    |  148.7    |  0.8965   |  0.9325   |  70.54    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.919119	val's rmse: 1.0367
# [2000]	train's rmse: 0.823315	val's rmse: 1.03376
# [3000]	train's rmse: 0.747645	val's rmse: 1.03336
# Early stopping, best iteration is:
# [2900]	train's rmse: 0.754505	val's rmse: 1.03286
# QWK score is 0.42315656409900426
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.915852	val's rmse: 1.06048
# [2000]	train's rmse: 0.821058	val's rmse: 1.05742
# Early stopping, best iteration is:
# [2025]	train's rmse: 0.818928	val's rmse: 1.05735
# QWK score is 0.4415588867639689
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.915008	val's rmse: 1.04543
# [2000]	train's rmse: 0.820006	val's rmse: 1.04229
# Early stopping, best iteration is:
# [1636]	train's rmse: 0.852027	val's rmse: 1.04206
# QWK score is 0.4262171866145673
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.916763	val's rmse: 1.04874
# [2000]	train's rmse: 0.821334	val's rmse: 1.04112
# Early stopping, best iteration is:
# [2055]	train's rmse: 0.816677	val's rmse: 1.04085
# QWK score is 0.4467304005496213
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.913892	val's rmse: 1.06524
# [2000]	train's rmse: 0.81834	val's rmse: 1.06176
# Early stopping, best iteration is:
# [2071]	train's rmse: 0.812694	val's rmse: 1.06142
# QWK score is 0.4604216744880957
# |  53       |  0.4399   |  0.5148   |  1.051    |  0.5009   |  1.121    |  98.74    |  10.82    |  148.2    |  0.7521   |  0.5963   |  70.01    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.886972	val's rmse: 1.03663
# [2000]	train's rmse: 0.780467	val's rmse: 1.03404
# [3000]	train's rmse: 0.694562	val's rmse: 1.03359
# Early stopping, best iteration is:
# [2536]	train's rmse: 0.733015	val's rmse: 1.03293
# QWK score is 0.4168026465948068
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.884442	val's rmse: 1.06065
# [2000]	train's rmse: 0.776839	val's rmse: 1.05828
# Early stopping, best iteration is:
# [1765]	train's rmse: 0.79921	val's rmse: 1.0581
# QWK score is 0.43839467524148334
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.883183	val's rmse: 1.0445
# [2000]	train's rmse: 0.777039	val's rmse: 1.04243
# Early stopping, best iteration is:
# [2168]	train's rmse: 0.761702	val's rmse: 1.04211
# QWK score is 0.4058650067383629
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.885929	val's rmse: 1.0448
# [2000]	train's rmse: 0.777212	val's rmse: 1.03773
# [3000]	train's rmse: 0.691472	val's rmse: 1.03699
# Early stopping, best iteration is:
# [2670]	train's rmse: 0.718343	val's rmse: 1.03669
# QWK score is 0.44891938264226505
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.880704	val's rmse: 1.06669
# [2000]	train's rmse: 0.771722	val's rmse: 1.06353
# Early stopping, best iteration is:
# [2072]	train's rmse: 0.764812	val's rmse: 1.06324
# QWK score is 0.4510417821838354
# |  54       |  0.4358   |  0.6578   |  1.146    |  0.6114   |  0.3478   |  90.95    |  10.87    |  147.3    |  0.3533   |  0.4324   |  72.05    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.883619	val's rmse: 1.03617
# [2000]	train's rmse: 0.772653	val's rmse: 1.03364
# [3000]	train's rmse: 0.69027	val's rmse: 1.03396
# Early stopping, best iteration is:
# [2564]	train's rmse: 0.723665	val's rmse: 1.03303
# QWK score is 0.43337116728159797
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.880682	val's rmse: 1.06043
# [2000]	train's rmse: 0.769907	val's rmse: 1.05966
# Early stopping, best iteration is:
# [1833]	train's rmse: 0.78621	val's rmse: 1.05911
# QWK score is 0.4126787217302158
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.879812	val's rmse: 1.04341
# Early stopping, best iteration is:
# [1491]	train's rmse: 0.821583	val's rmse: 1.04151
# QWK score is 0.41956433914750224
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.882155	val's rmse: 1.0475
# [2000]	train's rmse: 0.770302	val's rmse: 1.04146
# [3000]	train's rmse: 0.688156	val's rmse: 1.04062
# Early stopping, best iteration is:
# [3461]	train's rmse: 0.657302	val's rmse: 1.04027
# QWK score is 0.4418577390903623
# Training until validation scores don't improve for 500 rounds.
# [1000]	train's rmse: 0.878399	val's rmse: 1.0663
# [2000]	train's rmse: 0.766298	val's rmse: 1.06332
# Early stopping, best iteration is:
# [2034]	train's rmse: 0.763056	val's rmse: 1.06304
# QWK score is 0.44642134720577964
# |  55       |  0.437    |  0.6169   |  1.183    |  0.693    |  0.6896   |  95.55    |  11.56    |  141.0    |  0.1453   |  0.9754   |  70.19    |
# =================================================================================================================================================

# %%
print(lgbm_bayesopt.max["params"])
# Out:
# {'bagging_fraction': 0.5131784591803071, 'bagging_freq': 2.7474207792864034, 'feature_fraction': 0.5990835151831011, 'lambda_l2': 0.039859504060058226, 'max_bin': 91.83795752943023, 'max_depth': 11.362457223936937, 'min_child_samples': 146.80325270526626, 'min_child_weight': 0.367097814846602, 'min_split_gain': 0.07547218293002156, 'num_leaves': 70.0435985470157}

# %%
def LGBM_bayesian(num_leaves,
                  max_depth,
                  max_bin,
                  bagging_fraction,
                  bagging_freq,
                  feature_fraction,
                  min_split_gain,
                  min_child_samples,
                  min_child_weight,
                  lambda_l2):
    
    params = {"application": "regression",
              "boosting": "gbdt",
              "metric": "rmse",
              "learning_rate": 0.005,
              "num_leaves": int(num_leaves),
              "max_depth": int(max_depth),
              "max_bin": int(max_bin),
              "bagging_fraction": bagging_fraction,
              "bagging_freq": int(bagging_freq),
              "feature_fraction": feature_fraction,
              "min_split_gain": min_split_gain,
              "lambda_l2": lambda_l2,
              "min_child_samples": int(min_child_samples),
              "min_child_weight": min_child_weight,
              "verbosity": -1,
              "num_threads": 4,
              "seed": seed}
    
    oof_pred = np.zeros((train.shape[0]))
    kfold = StratifiedKFold(n_splits = 5, random_state = seed, shuffle = True)
    
    for i, (train_idx, val_idx) in enumerate(kfold.split(train_X, rescuerID)):
        evals_results = {}
        X_train, y_train = train_X.iloc[train_idx], target[train_idx]
        X_val, y_val = train_X.iloc[val_idx], target[val_idx]
    
        dtrain = lgbm.Dataset(X_train, label = y_train)
        dval = lgbm.Dataset(X_val, label = y_val)
        del X_train, y_train; gc.collect()
    
        model = lgbm.train(params, dtrain, valid_sets = [dtrain, dval], 
                           valid_names = ["train", "val"], evals_result = evals_results,
                           num_boost_round = 20000, early_stopping_rounds = 500,
                           verbose_eval = 1000)
        del dtrain, dval; gc.collect()
    
        n_estimator = model.best_iteration
        val_pred = model.predict(X_val, num_iteration = n_estimator)
        oof_pred[val_idx] = val_pred

        opt_round = OptimizedRounder()
        opt_round.fit(val_pred, y_val)
        coefficients = opt_round.coefficients()
        val_pred = opt_round.predict(val_pred, coefficients)
        qwk = quadratic_weighted_kappa(y_val, val_pred)
        print("QWK score is {}".format(qwk))
        del X_val, y_val; gc.collect()
            
    loss = -sqrt(mean_squared_error(target, oof_pred))
    
    return loss

# %%
lgbm_bayesopt = BayesianOptimization(LGBM_bayesian, bounds, random_state = seed)

# with warnings.catch_warnings():
#     warnings.filterwarnings("ignore")
#     lgbm_bayesopt.maximize(init_points = 5, n_iter = 25, acq = "ucb")

# %%
# print(lgbm_bayesopt.max["params"])
